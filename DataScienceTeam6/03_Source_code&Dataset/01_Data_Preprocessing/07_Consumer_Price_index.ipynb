# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Read excel file

Consumer_Price_index = pd.read_excel("../00_Data/Original_data/Consumer_Price_index.xlsx")
Consumer_Price_index.head()
# Out:
#         시점  Nationwide Consumer Price Index
# 0  2024.04                           113.99
# 1  2024.03                           113.94
# 2  2024.02                           113.77
# 3  2024.01                           113.15
# 4  2023.12                           112.71

# %%
Consumer_Price_index.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160 entries, 0 to 159
# Data columns (total 2 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   시점                               160 non-null    float64
#  1   Nationwide Consumer Price Index  160 non-null    float64
# dtypes: float64(2)
# memory usage: 2.6 KB

# %%
Consumer_Price_index_drop = Consumer_Price_index.dropna()
Consumer_Price_index_drop
# Out:
#           시점  Nationwide Consumer Price Index
# 0    2024.04                          113.990
# 1    2024.03                          113.940
# 2    2024.02                          113.770
# 3    2024.01                          113.150
# 4    2023.12                          112.710
# ..       ...                              ...
# 155  2011.05                           89.497
# 156  2011.04                           89.325
# 157  2011.03                           89.238
# 158  2011.02                           88.892
# 159  2011.01                           88.288
#
# [160 rows x 2 columns]

# %%
Consumer_Price_index_drop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160 entries, 0 to 159
# Data columns (total 2 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   시점                               160 non-null    float64
#  1   Nationwide Consumer Price Index  160 non-null    float64
# dtypes: float64(2)
# memory usage: 2.6 KB

# %%
Consumer_Price_index_drop.describe()
# Out:
#                 시점  Nationwide Consumer Price Index
# count   160.000000                       160.000000
# mean   2017.239000                        98.656000
# std       3.863316                         6.430109
# min    2011.010000                        88.288000
# 25%    2014.047500                        94.118500
# 50%    2017.085000                        97.665000
# 75%    2020.342500                       100.815000
# max    2024.040000                       113.990000

# %%
Consumer_Price_index_drop.dtypes
# Out:
# 시점                                 float64
# Nationwide Consumer Price Index    float64
# dtype: object

# %%
from datetime import datetime, timedelta
from scipy.interpolate import interp1d

# Given monthly data
Consumer_Price_index_drop = Consumer_Price_index_drop.rename(columns={'시점': 'Date'})
Consumer_Price_index_drop['Date'] = Consumer_Price_index_drop['Date'].astype(str)
monthly_data = Consumer_Price_index_drop.values

# Convert year-month formatted strings to date objects
dates = [datetime.strptime(year_month, "%Y.%m") for year_month, _ in monthly_data]

# Values of monthly data
values = [value for _, value in monthly_data]

# Sort date and value data by date
sorted_indices = np.argsort(dates)
sorted_dates = [dates[i] for i in sorted_indices]
sorted_values = [values[i] for i in sorted_indices]

# Create an interpolation function
f = interp1d([date.timestamp() for date in sorted_dates], sorted_values, kind='linear')

# Generate interpolated daily data
start_date = sorted_dates[0]
end_date = sorted_dates[-1]

daily_dates = []
current_date = start_date
while current_date <= end_date:
    daily_dates.append(current_date)
    current_date += timedelta(days=1)

daily_values = [f(date.timestamp()) for date in daily_dates]

# Print the result
daily_data = list(zip(daily_dates, daily_values))

interpolation_function_Consumer_Price_index_drop = pd.DataFrame(daily_data, columns=Consumer_Price_index_drop.columns)

interpolation_function_Consumer_Price_index_drop['Date'] = interpolation_function_Consumer_Price_index_drop['Date'].dt.strftime('%Y-%m-%d')

interpolation_function_Consumer_Price_index_drop
# Out:
# 일간 데이터: [(datetime.datetime(2011, 1, 1, 0, 0), array(90.448)), (datetime.datetime(2011, 1, 2, 0, 0), array(90.39780645)), (datetime.datetime(2011, 1, 3, 0, 0), array(90.3476129)), (datetime.datetime(2011, 1, 4, 0, 0), array(90.29741935)), (datetime.datetime(2011, 1, 5, 0, 0), array(90.24722581)), (datetime.datetime(2011, 1, 6, 0, 0), array(90.19703226)), (datetime.datetime(2011, 1, 7, 0, 0), array(90.14683871)), (datetime.datetime(2011, 1, 8, 0, 0), array(90.09664516)), (datetime.datetime(2011, 1, 9, 0, 0), array(90.04645161)), (datetime.datetime(2011, 1, 10, 0, 0), array(89.99625806)), (datetime.datetime(2011, 1, 11, 0, 0), array(89.94606452)), (datetime.datetime(2011, 1, 12, 0, 0), array(89.89587097)), (datetime.datetime(2011, 1, 13, 0, 0), array(89.84567742)), (datetime.datetime(2011, 1, 14, 0, 0), array(89.79548387)), (datetime.datetime(2011, 1, 15, 0, 0), array(89.74529032)), (datetime.datetime(2011, 1, 16, 0, 0), array(89.69509677)), (datetime.datetime(2011, 1, 17, 0, 0), array(89.64490323)), (datetime.datetime(2011, 1, 18, 0, 0), array(89.59470968)), (datetime.datetime(2011, 1, 19, 0, 0), array(89.54451613)), (datetime.datetime(2011, 1, 20, 0, 0), array(89.49432258)), (datetime.datetime(2011, 1, 21, 0, 0), array(89.44412903)), (datetime.datetime(2011, 1, 22, 0, 0), array(89.39393548)), (datetime.datetime(2011, 1, 23, 0, 0), array(89.34374194)), (datetime.datetime(2011, 1, 24, 0, 0), array(89.29354839)), (datetime.datetime(2011, 1, 25, 0, 0), array(89.24335484)), (datetime.datetime(2011, 1, 26, 0, 0), array(89.19316129)), (datetime.datetime(2011, 1, 27, 0, 0), array(89.14296774)), (datetime.datetime(2011, 1, 28, 0, 0), array(89.09277419)), (datetime.datetime(2011, 1, 29, 0, 0), array(89.04258065)), (datetime.datetime(2011, 1, 30, 0, 0), array(88.9923871)), (datetime.datetime(2011, 1, 31, 0, 0), array(88.94219355)), (datetime.datetime(2011, 2, 1, 0, 0), array(88.892)), (datetime.datetime(2011, 2, 2, 0, 0), array(88.90435714)), (datetime.datetime(2011, 2, 3, 0, 0), array(88.91671429)), (datetime.datetime(2011, 2, 4, 0, 0), array(88.92907143)), (datetime.datetime(2011, 2, 5, 0, 0), array(88.94142857)), (datetime.datetime(2011, 2, 6, 0, 0), array(88.95378571)), (datetime.datetime(2011, 2, 7, 0, 0), array(88.96614286)), (datetime.datetime(2011, 2, 8, 0, 0), array(88.9785)), (datetime.datetime(2011, 2, 9, 0, 0), array(88.99085714)), (datetime.datetime(2011, 2, 10, 0, 0), array(89.00321429)), (datetime.datetime(2011, 2, 11, 0, 0), array(89.01557143)), (datetime.datetime(2011, 2, 12, 0, 0), array(89.02792857)), (datetime.datetime(2011, 2, 13, 0, 0), array(89.04028571)), (datetime.datetime(2011, 2, 14, 0, 0), array(89.05264286)), (datetime.datetime(2011, 2, 15, 0, 0), array(89.065)), (datetime.datetime(2011, 2, 16, 0, 0), array(89.07735714)), (datetime.datetime(2011, 2, 17, 0, 0), array(89.08971429)), (datetime.datetime(2011, 2, 18, 0, 0), array(89.10207143)), (datetime.datetime(2011, 2, 19, 0, 0), array(89.11442857)), (datetime.datetime(2011, 2, 20, 0, 0), array(89.12678571)), (datetime.datetime(2011, 2, 21, 0, 0), array(89.13914286)), (datetime.datetime(2011, 2, 22, 0, 0), array(89.1515)), (datetime.datetime(2011, 2, 23, 0, 0), array(89.16385714)), (datetime.datetime(2011, 2, 24, 0, 0), array(89.17621429)), (datetime.datetime(2011, 2, 25, 0, 0), array(89.18857143)), (datetime.datetime(2011, 2, 26, 0, 0), array(89.20092857)), (datetime.datetime(2011, 2, 27, 0, 0), array(89.21328571)), (datetime.datetime(2011, 2, 28, 0, 0), array(89.22564286)), (datetime.datetime(2011, 3, 1, 0, 0), array(89.238)), (datetime.datetime(2011, 3, 2, 0, 0), array(89.24080645)), (datetime.datetime(2011, 3, 3, 0, 0), array(89.2436129)), (datetime.datetime(2011, 3, 4, 0, 0), array(89.24641935)), (datetime.datetime(2011, 3, 5, 0, 0), array(89.24922581)), (datetime.datetime(2011, 3, 6, 0, 0), array(89.25203226)), (datetime.datetime(2011, 3, 7, 0, 0), array(89.25483871)), (datetime.datetime(2011, 3, 8, 0, 0), array(89.25764516)), (datetime.datetime(2011, 3,  ...
#             Date Nationwide Consumer Price Index
# 0     2011-01-01                          90.448
# 1     2011-01-02                90.3978064516129
# 2     2011-01-03                90.3476129032258
# 3     2011-01-04               90.29741935483871
# 4     2011-01-05               90.24722580645161
# ...          ...                             ...
# 4835  2024-03-28              113.98354838709677
# 4836  2024-03-29              113.98516129032258
# 4837  2024-03-30              113.98677419354838
# 4838  2024-03-31              113.98838709677419
# 4839  2024-04-01                          113.99
#
# [4840 rows x 2 columns]

# %%
plt.figure(figsize=(10, 5))
plt.plot(interpolation_function_Consumer_Price_index_drop['Date'], interpolation_function_Consumer_Price_index_drop['Nationwide Consumer Price Index'], color='blue')
plt.title('Nationwide Consumer Price Index')
plt.xlabel('Date')
plt.ylabel('Nationwide Consumer Price Index')
# Out:
# Text(0, 0.5, 'Nationwide Consumer Price Index')

# %%
interpolation_function_Consumer_Price_index_drop.to_excel("../00_Data/Transformed_data/interpolation_function_Consumer_Price_index_drop.xlsx")
